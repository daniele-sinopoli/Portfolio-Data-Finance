# %%
import pandas as pd

print(" Ambiente data science")

dati={"esami":["stat", "R>icerca", "basi"],
      "Difficolta":[8 , 9 , 7],
      "status":["fatto", "fatto", "fatto"]}

tabella = pd.DataFrame(dati)
tabella
# Out:
#  Ambiente data science
#       esami  Difficolta status
# 0      stat           8  fatto
# 1  R>icerca           9  fatto
# 2      basi           7  fatto
